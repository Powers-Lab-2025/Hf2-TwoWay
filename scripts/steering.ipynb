# %%
pip install git-sim
# Out:
# Collecting git-sim
#   Downloading git_sim-0.3.5-py3-none-any.whl.metadata (27 kB)
# Collecting git-dummy (from git-sim)
#   Downloading git_dummy-0.1.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: gitpython in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from git-sim) (3.1.40)
# Requirement already satisfied: manim in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from git-sim) (0.19.0)
# Collecting opencv-python-headless (from git-sim)
#   Downloading opencv-python-headless-4.11.0.86.tar.gz (95.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 MB 3.3 MB/s eta 0:00:0000:0100:01m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydantic-settings (from git-sim)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting typer (from git-sim)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: fonttools in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from git-sim) (4.51.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from gitpython->git-sim) (4.0.11)
# Requirement already satisfied: Pillow>=9.1 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (10.3.0)
# Requirement already satisfied: Pygments>=2.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (2.15.1)
# Requirement already satisfied: av<14.0.0,>=9.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (13.1.0)
# Requirement already satisfied: beautifulsoup4>=4.12 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (4.12.2)
# Requirement already satisfied: click>=8.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (8.1.7)
# Requirement already satisfied: cloup>=2.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (3.0.7)
# Requirement already satisfied: decorator>=4.3.2 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (4.4.2)
# Requirement already satisfied: isosurfaces>=0.1.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (0.1.2)
# Requirement already satisfied: manimpango<1.0.0,>=0.5.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (0.6.0)
# Requirement already satisfied: mapbox-earcut>=1.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (1.0.3)
# Requirement already satisfied: moderngl<6.0.0,>=5.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (5.12.0)
# Requirement already satisfied: moderngl-window>=2.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (3.1.1)
# Requirement already satisfied: networkx>=2.6 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (3.1)
# Requirement already satisfied: numpy>=2.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (2.0.2)
# Requirement already satisfied: pycairo<2.0.0,>=1.13 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (1.28.0)
# Requirement already satisfied: pydub>=0.20.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (0.25.1)
# Requirement already satisfied: rich>=12.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (13.3.5)
# Requirement already satisfied: scipy>=1.13.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (1.13.1)
# Requirement already satisfied: screeninfo>=0.7 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (0.8.1)
# Requirement already satisfied: skia-pathops>=0.7.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (0.8.0.post2)
# Requirement already satisfied: srt>=3.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (3.5.3)
# Requirement already satisfied: svgelements>=1.8.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (1.9.6)
# Requirement already satisfied: tqdm>=4.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (4.11.0)
# Requirement already satisfied: watchdog>=2.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from manim->git-sim) (2.1.6)
# Collecting pydantic>=2.7.0 (from pydantic-settings->git-sim)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from pydantic-settings->git-sim) (0.21.0)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings->git-sim)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->git-sim)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.12->manim->git-sim) (2.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->git-sim) (5.0.1)
# Requirement already satisfied: glcontext>=3.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from moderngl<6.0.0,>=5.0.0->manim->git-sim) (3.0.0)
# Requirement already satisfied: pyglet>=2.0.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from moderngl-window>=2.0.0->manim->git-sim) (2.1.6)
# Requirement already satisfied: pyglm<3,>=2.7.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from moderngl-window>=2.0.0->manim->git-sim) (2.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2.7.0->pydantic-settings->git-sim) (0.6.0)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.7.0->pydantic-settings->git-sim)
#   Downloading pydantic_core-2.33.2-cp39-cp39-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting typing-extensions>=4.0.0 (from manim->git-sim)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from rich>=12.0.0->manim->git-sim) (2.2.0)
# Requirement already satisfied: Cython in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from screeninfo>=0.7->manim->git-sim) (3.0.10)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from screeninfo>=0.7->manim->git-sim) (8.5)
# Requirement already satisfied: mdurl~=0.1 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->manim->git-sim) (0.1.0)
# Requirement already satisfied: pyobjc-core>=8.5 in /Users/alforest/opt/anaconda3/lib/python3.9/site-packages (from pyobjc-framework-Cocoa->screeninfo>=0.7->manim->git-sim) (8.5)
# Downloading git_sim-0.3.5-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 kB 6.3 MB/s eta 0:00:00
# Downloading git_dummy-0.1.2-py3-none-any.whl (13 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.3 MB/s eta 0:00:00
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 4.5 MB/s eta 0:00:00
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.33.2-cp39-cp39-macosx_10_12_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.9 MB/s eta 0:00:0000:0100:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.2 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Building wheels for collected packages: opencv-python-headless
#   Building wheel for opencv-python-headless (pyproject.toml) ... \

# %%
from pathlib import Path
from hf2.conversion import convert_dyn_to_xyz

dyn_path = Path("/Users/alforest/Desktop/Documents/SomeSeeds/SimTree/F5/425/data/2/F5_ramp.dyn")

try:
    converted_path = convert_dyn_to_xyz(
        dyn_path,
        ref_prefix="F8_ramp",
        verbose=True
    )
    print(f"Success! Converted file written to: {converted_path}")
except Exception as e:
    print(f"Conversion failed: {e}")
# Out:
# [DYN] F5_ramp.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/SomeSeeds/SimTree/F5/425/data/2/XYZs/F5_ramp_converted.xyz
# Success! Converted file written to: /Users/alforest/Desktop/Documents/SomeSeeds/SimTree/F5/425/data/2/XYZs/F5_ramp_converted.xyz

# %%
import sys
if 'hf2.analyis' in sys.modules:
    del sys.modules['hf2.analyis']

# %%
import importlib

import hf2
import hf2.config
import hf2.analysis
import hf2.conductor
import hf2.coordinator

importlib.reload(hf2.config)
#importlib.reload(hf2.analysis)
importlib.reload(hf2.conductor)
importlib.reload(hf2.coordinator)
importlib.reload(hf2)

print(hf2.config.REF_XYZ_PREFIX)

from hf2.coordinator import SimulationManager

sim_root = "/Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest"
manager = SimulationManager(sim_root, verbose=True)
manager.run(interval=2.5)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# F7_ramp
# [MANAGER] Monitoring simulation root: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest
# [TINKER START] Running in /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-6:
#   ~/TinkerExp/bin/dynamic F7_ramp 200 5 1 4 1 300 1 > F7_ramp.001.out
# sh: /Users/alforest/TinkerExp/bin/dynamic: No such file or directory
# sh: /Users/alforest/TinkerExp/bin/dynamic: No such file or directory
# sh: /Users/alforest/TinkerExp/bin/dynamic: No such file or directory
# sh: /Users/alforest/TinkerExp/bin/dynamic: No such file or directory
# [MANAGER] Activated new path: A1-6
# [TINKER START] Running in /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-2:
#   ~/TinkerExp/bin/dynamic F7_ramp 200 5 1 4 1 300 1 > F7_ramp.001.out
# [MANAGER] Activated new path: A1-5-1-1-2
# [TINKER START] Running in /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1:
#   ~/TinkerExp/bin/dynamic F7_ramp 200 5 1 4 1 300 1 > F7_ramp.001.out
# [MANAGER] Activated new path: A1-5-1-1
# [TINKER START] Running in /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-1:
#   ~/TinkerExp/bin/dynamic F7_ramp 200 5 1 4 1 300 1 > F7_ramp.001.out
# [MANAGER] Activated new path: A1-5-1-1-1
# [MANAGER] Starting main loop with 2.5s interval.
# [MONITOR] New dyn file detected: F7_ramp.dyn
# [DYN] F7_ramp.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-6/XYZs/F7_ramp_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp2.dyn
# [DYN] F7_ramp2.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-6/XYZs/F7_ramp2_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp3.dyn
# [DYN] F7_ramp3.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-6/XYZs/F7_ramp3_converted.xyz
# [ANALYSIS] Path A1-6 suggested action code: 4
# [CONTINUE] A1-6 continuing without changes.
# [MONITOR] New dyn file detected: F7_ramp.dyn
# [DYN] F7_ramp.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-2/XYZs/F7_ramp_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp2.dyn
# [DYN] F7_ramp2.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-2/XYZs/F7_ramp2_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp3.dyn
# [DYN] F7_ramp3.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-2/XYZs/F7_ramp3_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp4.dyn
# [DYN] F7_ramp4.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-2/XYZs/F7_ramp4_converted.xyz
# [ANALYSIS] Path A1-5-1-1-2 suggested action code: 4
# [CONTINUE] A1-5-1-1-2 continuing without changes.
# [MONITOR] New dyn file detected: F7_ramp.dyn
# [DYN] F7_ramp.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1/XYZs/F7_ramp_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp2.dyn
# [DYN] F7_ramp2.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1/XYZs/F7_ramp2_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp3.dyn
# [DYN] F7_ramp3.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1/XYZs/F7_ramp3_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp4.dyn
# [DYN] F7_ramp4.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1/XYZs/F7_ramp4_converted.xyz
# [ANALYSIS] Path A1-5-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1 continuing without changes.
# [MONITOR] New dyn file detected: F7_ramp.dyn
# [DYN] F7_ramp.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-1/XYZs/F7_ramp_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp2.dyn
# [DYN] F7_ramp2.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-1/XYZs/F7_ramp2_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp3.dyn
# [DYN] F7_ramp3.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-1/XYZs/F7_ramp3_converted.xyz
# [MONITOR] New dyn file detected: F7_ramp4.dyn
# [DYN] F7_ramp4.dyn — 18000 atoms
# Title: User Made
# [XYZ] Wrote bonded .xyz to: /Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest/A1-5-1-1-1/XYZs/F7_ramp4_converted.xyz
# [ANALYSIS] Path A1-5-1-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1-1 continuing without changes.
#
# === Simulation Status ===
# Uptime: 0:00:04.505543
# Active paths: 4
# Queued paths: 0
# Recent spinoffs:
# =========================
#
# [ANALYSIS] Path A1-6 suggested action code: 4
# [CONTINUE] A1-6 continuing without changes.
# [ANALYSIS] Path A1-5-1-1-2 suggested action code: 4
# [CONTINUE] A1-5-1-1-2 continuing without changes.
# [ANALYSIS] Path A1-5-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1 continuing without changes.
# [ANALYSIS] Path A1-5-1-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1-1 continuing without changes.
#
# === Simulation Status ===
# Uptime: 0:00:09.070988
# Active paths: 4
# Queued paths: 0
# Recent spinoffs:
# =========================
#
# [ANALYSIS] Path A1-6 suggested action code: 4
# [CONTINUE] A1-6 continuing without changes.
# [ANALYSIS] Path A1-5-1-1-2 suggested action code: 4
# [CONTINUE] A1-5-1-1-2 continuing without changes.
# [ANALYSIS] Path A1-5-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1 continuing without changes.
# [ANALYSIS] Path A1-5-1-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1-1 continuing without changes.
#
# === Simulation Status ===
# Uptime: 0:00:13.806679
# Active paths: 4
# Queued paths: 0
# Recent spinoffs:
# =========================
#
# [ANALYSIS] Path A1-6 suggested action code: 4
# [CONTINUE] A1-6 continuing without changes.
# [ANALYSIS] Path A1-5-1-1-2 suggested action code: 4
# [CONTINUE] A1-5-1-1-2 continuing without changes.
# [ANALYSIS] Path A1-5-1-1 suggested action code: 4
# [CONTINUE] A1-5-1-1 continuing without changes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      19 sim_root = "/Users/alforest/Desktop/Documents/Hf2/testfolder/SimulationTest"
#      20 manager = SimulationManager(sim_root, verbose=True)
# ---> 21 manager.run(interval=2.5)
#
# File ~/Desktop/Documents/Hf2/Hf2/hf2/coordinator.py:129, in SimulationManager.run(self, interval)
#     127 while True:
#     128     self.scan_for_new_paths()
# --> 129     self.update_all()
#     130     self.log_status()
#     131     time.sleep(interval)
#
# File ~/Desktop/Documents/Hf2/Hf2/hf2/coordinator.py:71, in SimulationManager.update_all(self)
#      69 for label, conductor in list(self.active_paths.items()):
#      70     try:
# ---> 71         still_active = conductor.update()
#      72         if not still_active:
#      73             to_remove.append(label)
#
# File ~/Desktop/Documents/Hf2/Hf2/hf2/conductor.py:181, in SimulationPath.update(self)
#     176 """
#     177 One complete step: check for new .dyn files, convert, and run analysis.
#     178 Called externally by the simulation manager.
#     179 """
#     180 self.monitor_and_convert()
# --> 181 return self.run_analysis()
#
# File ~/Desktop/Documents/Hf2/Hf2/hf2/conductor.py:81, in SimulationPath.run_analysis(self)
#      79     return True
#      80 try:
# ---> 81     action = analysis(self.path / hf2.config.XYZ_SUBDIR)
#      82     if self.verbose:
#      83         print(f"[ANALYSIS] Path {self.label} suggested action code: {action}")
#
# File ~/Desktop/Documents/Hf2/Hf2/hf2/analysis.py:36, in analysis(xyz_dir)
#      33 latest = traj_files[-1]
#      34 previous = traj_files[-2]
# ---> 36 u_latest = mda.Universe(str(latest), format="TXYZ")
#      37 u_prev = mda.Universe(str(previous), format="TXYZ")
#      40 frags_latest = list(u_latest.select_atoms("all").fragments)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:375, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, in_memory_step, *coordinates, **kwargs)
#     370 coordinates = _resolve_coordinates(self.filename, *coordinates,
#     371                                    format=format,
#     372                                    all_coordinates=all_coordinates)
#     374 if coordinates:
# --> 375     self.load_new(coordinates, format=format, in_memory=in_memory,
#     376                 in_memory_step=in_memory_step, **kwargs)
#     378 if transformations:
#     379     if callable(transformations):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:580, in Universe.load_new(self, filename, format, in_memory, in_memory_step, **kwargs)
#     577 # supply number of atoms for readers that cannot do it for themselves
#     578 kwargs['n_atoms'] = self.atoms.n_atoms
# --> 580 self.trajectory = reader(filename, format=format, **kwargs)
#     581 if self.trajectory.n_atoms != len(self.atoms):
#     582     raise ValueError("The topology and {form} trajectory files don't"
#     583                      " have the same number of atoms!\n"
#     584                      "Topology number of atoms {top_n_atoms}\n"
#    (...)
#     588                          fname=filename,
#     589                          trj_n_atoms=self.trajectory.n_atoms))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/lib/util.py:2553, in store_init_arguments.<locals>.wrapper(self, *args, **kwargs)
#    2551             else:
#    2552                 self._kwargs[key] = arg
# -> 2553 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/TXYZ.py:89, in TXYZReader.__init__(self, filename, **kwargs)
#      86         self.periodic = True
#      87 self.ts = self._Timestep(self.n_atoms, **self._ts_kwargs)
# ---> 89 self._read_next_timestep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/TXYZ.py:150, in TXYZReader._read_next_timestep(self, ts)
#     148 tmp_buf = []
#     149 for i in range(self.n_atoms):
# --> 150     tmp_buf.append(f.readline().split()[2:5])
#     151 ts.positions = tmp_buf
#     152 ts.frame += 1
#
# KeyboardInterrupt:
